# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os 
import math
import collections

# %%
image_data = pd.read_csv("Bill Gates RGB Image.csv")
image_data.head()
# Out:
#    X  Y    R    G    B
# 0  0  0  123  167  214
# 1  0  1  103  146  189
# 2  0  2   63  101  140
# 3  0  3   18   51   82
# 4  0  4    0   20   44

# %%
row = np.array([])
red = image_data['R'].values
blue = image_data['B'].values
green = image_data['G'].values
row = image_data['X'].values
col = image_data['Y'].values
m = np.max(row)
n = np.max(col)

# %%
def cvtPixilToImage(red,n,m):
    red_image = []
    count=0
    for i in range(n+1):
        row = np.array([])
        l = []
        for j in range(m+1):
            l.append(red[count])
            count+=1
        red_image.append(l)
    red_image = np.array(red_image)
    return red_image

red_image = cvtPixilToImage(red,n,m)
blue_image = cvtPixilToImage(blue,n,m)
green_image = cvtPixilToImage(green,n,m)
print(red_image.shape)
# Out:
# (160, 160)

# %%
#red color plotting
plt.imshow(red_image)

# %%
#plotting blue pixil
plt.imshow(blue_image)

# %%
#plotting green pixil
plt.imshow(green_image)

# %%
def cvtToRGB(red,blue,green,n,m):
    red_image = []
    count=0
    for i in range(n+1):
        row = np.array([])
        l = []
        for j in range(m+1):
            l.append([blue[count],green[count],red[count]]) 
            count+=1
        red_image.append(l)
    red_image = np.array(red_image)
    return red_image
rgb_image = cvtToRGB(red,blue,green,n,m)

# %%
plt.imshow(rgb_image)
